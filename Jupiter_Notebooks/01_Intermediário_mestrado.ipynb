# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import seaborn as sns
from google.colab import drive
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import graphviz
from google.cloud import bigquery
import pandas as pd

# %%
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# # Lendo notas

# %%
file_name = "Cr_BSI"
#file_name = "CrMat"
#file_name = "CrEngProd"
data_cr = pd.read_excel("/content/gdrive/My Drive/dados_mestrado/"+file_name+".xlsx")

# %%
data_cr
# Out:
#        ID_PESSOA                 NOME_PESSOA  ID_ALUNO   MATR_ALUNO  \
# 0           1200   André Luiz Bione Martinez      1200  20002210014
# 1           1200   André Luiz Bione Martinez      1200  20002210014
# 2           1200   André Luiz Bione Martinez      1200  20002210014
# 3           1200   André Luiz Bione Martinez      1200  20002210014
# 4           1200   André Luiz Bione Martinez      1200  20002210014
# ...          ...                         ...       ...          ...
# 48635     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48636     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48637     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48638     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48639     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
#
#       NUM_VERSAO                                         NOME_CURSO  \
# 0     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 1     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 2     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 3     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 4     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# ...          ...                                                ...
# 48635 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48636 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48637 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48638 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48639 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
#
#        COD_CURSO  ID_VERSAO_CURSO   ANO COD_ATIV_CURRIC  ... CH_PRATICA  \
# 0            210               13  2000         TME0012  ...        NaN
# 1            210               13  2000         TME0012  ...        NaN
# 2            210               13  2000         HHI0033  ...        NaN
# 3            210               13  2000         HHI0033  ...        NaN
# 4            210               13  2000         TIN0005  ...        NaN
# ...          ...              ...   ...             ...  ...        ...
# 48635        210              737  2023         TIN0106  ...        NaN
# 48636        210              737  2023         TMT0043  ...        NaN
# 48637        210              737  2023         TIN0206  ...        NaN
# 48638        210              737  2023         TIN0207  ...        NaN
# 48639        210              737  2023         TIN0208  ...        NaN
#
#        TOTAL_CARGA_HORARIA  CARGA_CURSO     DESCR_FORMA_INGRESSO ANO_INGRESSO  \
# 0                       90         3270          VE - Vestibular         2000
# 1                       90         3270          VE - Vestibular         2000
# 2                       60         3270          VE - Vestibular         2000
# 3                       60         3270          VE - Vestibular         2000
# 4                       60         3270          VE - Vestibular         2000
# ...                    ...          ...                      ...          ...
# 48635                   60         3000  SISU Ampla Concorrencia         2023
# 48636                   60         3000  SISU Ampla Concorrencia         2023
# 48637                   60         3000  SISU Ampla Concorrencia         2023
# 48638                   60         3000  SISU Ampla Concorrencia         2023
# 48639                   60         3000  SISU Ampla Concorrencia         2023
#
#       DESCR_FORMA_EVASAO  ANO_EVASAO  SEXO  CR_NO_PERIODO  CR_ATUAL
# 0      JUB - Jubilamento      2005.0     M           6.51    5.2071
# 1      JUB - Jubilamento      2005.0     M           6.51    5.2071
# 2      JUB - Jubilamento      2005.0     M           6.51    5.2071
# 3      JUB - Jubilamento      2005.0     M           6.51    5.2071
# 4      JUB - Jubilamento      2005.0     M           6.51    5.2071
# ...                  ...         ...   ...            ...       ...
# 48635         Sem evasão         NaN     M           8.84    8.8452
# 48636         Sem evasão         NaN     M           8.84    8.8452
# 48637         Sem evasão         NaN     M           8.84    8.8452
# 48638         Sem evasão         NaN     M           8.84    8.8452
# 48639         Sem evasão         NaN     M           8.84    8.8452
#
# [48640 rows x 28 columns]

# %%
import matplotlib.pyplot as plt

reprovados = data_cr [data_cr ['DESCR_SITUACAO'] == 'REP - Reprovado por nota/conceito']

# Calcular a contagem de reprovações para cada atividade curricular
reprovacao_counts = reprovados['NOME_ATIV_CURRIC'].value_counts()

# Pegar as 5 atividades com mais reprovações
top_5_reprovacoes = reprovacao_counts.head(10)

# Crie um gráfico de barras para as 5 atividades curriculares com mais reprovações
plt.figure(figsize=(10, 6))
top_5_reprovacoes.plot(kind='barh', color='skyblue')
plt.xlabel('Curricular Activities')
plt.ylabel('Quantity of Failures')
plt.title('Top 10 Curricular Activities with the Most Failures')
plt.show()

# %%
print(data_cr['MEDIA_FINAL'].max())
# Out:
# 42.0

# %%
def get_gpa_values(series, n=4):
    unique_values = series.unique()
    return np.pad(unique_values, (0, max(0, n - len(unique_values))), constant_values=np.nan)[:n]

# Aplicar a função get_gpa_values para cada grupo de NOME_PESSOA
gpa_values = data_cr.groupby('NOME_PESSOA')['CR_NO_PERIODO'].apply(get_gpa_values).apply(pd.Series)

# Renomear as colunas
gpa_values.columns = ['GPA1', 'GPA2', 'GPA3', 'GPA4']

# Unir as novas colunas ao DataFrame original
data_cr = data_cr.merge(gpa_values, left_on='NOME_PESSOA', right_index=True)

data_cr.head()
# Out:
#    ID_PESSOA                NOME_PESSOA  ID_ALUNO   MATR_ALUNO NUM_VERSAO  \
# 0       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
# 1       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
# 2       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
# 3       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
# 4       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
#
#                                           NOME_CURSO  COD_CURSO  \
# 0  Sistemas de Informação - Bacharelado - Turno I...        210
# 1  Sistemas de Informação - Bacharelado - Turno I...        210
# 2  Sistemas de Informação - Bacharelado - Turno I...        210
# 3  Sistemas de Informação - Bacharelado - Turno I...        210
# 4  Sistemas de Informação - Bacharelado - Turno I...        210
#
#    ID_VERSAO_CURSO   ANO COD_ATIV_CURRIC  ... ANO_INGRESSO  \
# 0               13  2000         TME0012  ...         2000
# 1               13  2000         TME0012  ...         2000
# 2               13  2000         HHI0033  ...         2000
# 3               13  2000         HHI0033  ...         2000
# 4               13  2000         TIN0005  ...         2000
#
#    DESCR_FORMA_EVASAO  ANO_EVASAO SEXO CR_NO_PERIODO CR_ATUAL  GPA1  GPA2  \
# 0   JUB - Jubilamento      2005.0    M          6.51   5.2071  6.51  4.67
# 1   JUB - Jubilamento      2005.0    M          6.51   5.2071  6.51  4.67
# 2   JUB - Jubilamento      2005.0    M          6.51   5.2071  6.51  4.67
# 3   JUB - Jubilamento      2005.0    M          6.51   5.2071  6.51  4.67
# 4   JUB - Jubilamento      2005.0    M          6.51   5.2071  6.51  4.67
#
#    GPA3  GPA4
# 0  0.75   NaN
# 1  0.75   NaN
# 2  0.75   NaN
# 3  0.75   NaN
# 4  0.75   NaN
#
# [5 rows x 32 columns]

# %%
import pandas as pd
import numpy as np

# Função para pegar o quarto valor único de uma série, ou DT_EVASAO em caso de exceção
def get_year4_value(series):
    try:
        unique_values = series.unique()
        if len(unique_values) >= 4:
            return unique_values[3]
        else:
            return np.nan
    except Exception as e:
        return np.nan

# Aplicar a função get_year4_value para cada grupo de NOME_PESSOA
year4_values = data_cr.groupby('NOME_PESSOA')['ANO'].apply(get_year4_value).reset_index()

# Renomear a coluna
year4_values.columns = ['NOME_PESSOA', 'year4']

# Função para substituir NaN por DT_EVASAO em caso de exceção
def replace_with_evasion(row):
    if pd.isna(row['year4']):
        evasion_value = data_cr.loc[data_cr['NOME_PESSOA'] == row['NOME_PESSOA'], 'ANO_EVASAO'].iloc[0]
        return evasion_value
    return row['year4']

# Aplicar a função de substituição
year4_values['year4'] = year4_values.apply(replace_with_evasion, axis=1)

# Unir a nova coluna ao DataFrame original
data_cr = data_cr.merge(year4_values, on='NOME_PESSOA', how='left')

print(data_cr.head())
# Out:
#    ID_PESSOA                NOME_PESSOA  ID_ALUNO   MATR_ALUNO NUM_VERSAO  \
# 0       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
# 1       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
# 2       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
# 3       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
# 4       1200  André Luiz Bione Martinez      1200  20002210014 2000-02-01
#
#                                           NOME_CURSO  COD_CURSO  \
# 0  Sistemas de Informação - Bacharelado - Turno I...        210
# 1  Sistemas de Informação - Bacharelado - Turno I...        210
# 2  Sistemas de Informação - Bacharelado - Turno I...        210
# 3  Sistemas de Informação - Bacharelado - Turno I...        210
# 4  Sistemas de Informação - Bacharelado - Turno I...        210
#
#    ID_VERSAO_CURSO   ANO COD_ATIV_CURRIC  ... DESCR_FORMA_EVASAO  ANO_EVASAO  \
# 0               13  2000         TME0012  ...  JUB - Jubilamento      2005.0
# 1               13  2000         TME0012  ...  JUB - Jubilamento      2005.0
# 2               13  2000         HHI0033  ...  JUB - Jubilamento      2005.0
# 3               13  2000         HHI0033  ...  JUB - Jubilamento      2005.0
# 4               13  2000         TIN0005  ...  JUB - Jubilamento      2005.0
#
#    SEXO CR_NO_PERIODO CR_ATUAL  GPA1  GPA2  GPA3  GPA4   year4
# 0     M          6.51   5.2071  6.51  4.67  0.75   NaN  2005.0
# 1     M          6.51   5.2071  6.51  4.67  0.75   NaN  2005.0
# 2     M          6.51   5.2071  6.51  4.67  0.75   NaN  2005.0
# 3     M          6.51   5.2071  6.51  4.67  0.75   NaN  2005.0
# 4     M          6.51   5.2071  6.51  4.67  0.75   NaN  2005.0
#
# [5 rows x 33 columns]

# %%
# prompt: Retorne linhas cujo GPA2 é NaN

#data_cr[data_cr["GPA2"].isna()]

# %% [markdown]
# # Pegando notas de matemática básica e programação

# %%
# prompt: Printe os valores únicos de data_cr["NOME_ATIV_CURRIC"]

print(data_cr["NOME_ATIV_CURRIC"].unique())
# Out:
# ['Cálculo Diferencial e Integral I' 'História da Ciência e da Tecnologia'
#  'Introdução à Lógica Computacional' 'Organização de Computadores'
#  'Programas Utilitários Básicos' 'TÉCNICAS DE PROGRAMAÇÃO I'
#  'Análise Empresarial e Administrativa' 'Estruturas Discretas'
#  'Produtividade Pessoal com Sistemas de Informação'
#  'TÉCNICAS DE PROGRAMAÇÃO II' 'Modelagem de Sistemas'
#  'Cálculo  Diferencial e Integral II' 'Administração Financeira'
#  'Análise e Projeto de Sistemas' 'Álgebra Linear' 'Estruturas de Dados'
#  'Probabilidade e Estatística' 'Sistemas Operacionais'
#  'Estudo de Domínios de Aplicação 1' 'Expressão Oral e Escrita'
#  'Linguagens Formais e Autômatos'
#  'Projeto e Construção de Sistemas com Ambiente de Programação'
#  'Redes de Computadores' 'Seminários sobre Optativas e Eletivas'
#  'Sistema de Banco de Dados' 'Análise de Algoritmos'
#  'Construção de Sistemas' 'Estudo de Domínios de Aplicação II'
#  'Iniciação à Pesquisa I' 'LEITURA E PRODUÇÃO DE TEXTOS'
#  'Programação Modular' 'Atividades Curriculares de Extensão-1'
#  'Atividades Curriculares de Extensão-2'
#  'Comunicação e Segurança de Dados' 'Distribuição e Concorrência'
#  'Empresa de Informática' 'Estudo de Domínios de Aplicação III'
#  'Groupware - Tecnologias de Apoio à Colaboração'
#  'Iniciação à Pesquisa II' 'Atividades Curriculares de Extensão-3'
#  'Banco de Dados em Ambiente Cliente-Servidor'
#  'Gerência de Projetos em Informática' 'Inteligência Artificial'
#  'Projeto de Graduação I' 'Projeto e Gerência de Redes Locais'
#  'Ambiente Operacional Unix' 'Atividades Curriculares de Extensão-4'
#  'Desenvolvimento de Software para Web' 'DIREITO E ÉTICA PROFISSIONAL'
#  'Projeto de Graduação II' 'Projeto e Construção de Sistemas com SGDB'
#  'Tópicos Avançados em Redes de Computadores'
#  'Banco de Dados Distribuídos e Datawarehousing'
#  'Tópicos Avançados em Engenharia de Software 2'
#  'Tópicos Avançados em Banco de Dados' 'Programação Linear'
#  'Tópicos Avançados em Algoritmos' 'Administração de Banco de Dados'
#  'Tópicos Avançados em Redes de Computadores 2'
#  'Tópicos Avançados em Banco de Dados 3'
#  'Tópicos Avançados em Bancos de dados 2'
#  'Tópicos Avançados em Engenaharia de Software III'
#  'ADMINISTRAÇÃO DE BANCO DE DADOS' 'ADMINISTRAÇÃO FINANCEIRA'
#  'AMBIENTE OPERACIONAL UNIX' 'ANÁLISE DE SISTEMAS' 'BANCO DE DADOS II'
#  'BANCO DE DADOS-I' 'CÁLCULO DIFERENCIAL E INTEGRAL II'
#  'CÁLCULO DIFERENCIAL E INTEGRAL-I' 'DESENVOLVIMENTO DE PÁGINAS WEB'
#  'DESENVOLVIMENTO DE SERVIDOR WEB' 'EMPREENDEDORISMO' 'ESTATÍSTICA'
#  'ESTRUTURAS DE DADOS-I' 'ESTRUTURAS DISCRETAS' 'FORMAÇÃO COMPLEMENTAR II'
#  'FORMAÇÃO COMPLEMENTAR III' 'FORMAÇÃO COMPLEMENTAR-I'
#  'FUNDAMENTOS DE SISTEMAS DE INFORMAÇÃO'
#  'GERÊNCIA DE DADOS EM AMBIENTES DISTRIBUÍDOS E PARALELOS'
#  'GERÊNCIA DE PROJETOS EM INFORMÁTICA' 'INTERAÇÃO HUMANO-COMPUTADOR'
#  'INTRODUÇÃO À LÓGICA COMPUTACIONAL' 'LINGUAGENS FORMAIS E AUTÔMATOS'
#  'ORGANIZAÇÃO DE COMPUTADORES' 'PROBABILIDADE' 'PROCESSOS DE SOFTWARE'
#  'PROJETO E CONSTRUÇÃO DE SISTEMAS'
#  'PROJETO E CONSTRUÇÃO DE SISTEMAS COMSGBD' 'REDES DE COMPUTADORES II'
#  'REDES DE COMPUTADORES-I' 'SISTEMAS OPERACIONAIS'
#  'TEORIAS E PRÁTICAS DISCURSIVAS NA ESFERA ACADÊMICA'
#  'TÉCNICAS DE PROGRAMAÇÃO-I'
#  'TÓPICOS AVANÇADOS EM REDES DE COMPUTADORES-I' 'ANÁLISE DE ALGORITMOS'
#  'ESTRUTURAS DE DADOS II' 'MATEMÁTICA BÁSICA' 'PROGRAMAÇÃO MODULAR'
#  'PROJETO DE GRADUAÇÃO II' 'PROJETO DE GRADUAÇÃO-I'
#  'GESTÃO DE PROCESSOS DE NEGÓCIOS'
#  'FUNDAMENTOS DE REPRESENTAÇÃO DE CONHECIMENTO E RACIOCÍNIO'
#  'TÓPICOS AVANÇADOS EM BANCO DE DADOS-I'
#  'TÓPICOS AVANÇADOS EM REDES DE COMPUTADORES II' 'INTELIGÊNCIA ARTIFICIAL'
#  'INFORMÁTICA NA EDUCAÇÃO' 'TÓPICOS AVANÇADOS EM BANCO DE DADOS III'
#  'TÓPICOS AVANÇADOS EM REDES DE COMPUTADORES III'
#  'FORMAÇÃO COMPLEMENTAR IV' 'Algoritmos para Problemas Combinatórios'
#  'Sistemas Multimídia' 'Fluxo em Redes' 'PROGRAMAÇÃO LINEAR'
#  'ALGORITMOS PARA PROBLEMAS COMBINATÓRIOS'
#  'COMPUTAÇÃO GRÁFICA E PROCESSAMENTO DE IMAGENS'
#  'TÓPICOS AVANÇADOS EM ALGORITMOS-I' 'SISTEMAS COLABORATIVOS'
#  'TÓPICOS AVANÇADOS EM BANCO DE DADOS II'
#  'COMUNICAÇÃO E SEGURANÇA DE DADOS' 'SISTEMAS MULTIMÍDIA' 'Compiladores'
#  'Tópicos Avançados em Engenharia de Software'
#  'TÓPICOS AVANÇADOS EM ENGENHARIA DE SOFTWARE II'
#  'Tópicos Avançados em Redes de Computadores 3'
#  'Língua Brasileira de Sinais'
#  'Computação Gráfica e Processamento de Imagem' 'FLUXOS EM REDES'
#  'Desenvolvimento Baseado em Componentes'
#  'TÓPICOS AVANÇADOS EM ENGENHARIA DE SOFTWARE-I'
#  'EDUCAÇÃO AMBIENTAL E CIDADANIA' 'COMPILADORES'
#  'Algoritmos e Programação' 'Arquitetura de Computadores' 'Automação'
#  'Empreendedorismo e Inovação' 'Engenharia de Software I'
#  'Estruturas de Dados Avançadas' 'Fundamentos de Cálculo'
#  'Fundamentos de Gestão Organizacional'
#  'Fundamentos de Sistemas de Informação' 'Interação Humano-Computador'
#  'Modelagem da Informação' 'Projeto de Aplicações com Dados Abertos'
#  'Projeto Integrador I' 'Redes Móveis e Computação Ubíqua'
#  'Técnicas de Programação' 'TUTORIA COMPUTAÇÃO II'
#  'Atividades de Extensão I' 'Engenharia de Software II'
#  'Estruturas Discretas com Algoritmos'
#  'Linguagens e Paradigmas de Programação' 'Novas Formas de Economia'
#  'Probabilidade' 'Sistemas Distribuídos'
#  'Tópicos em Processos de Software' 'Projeto Integrador II'
#  'Armazenamento e Gestão de Dados' 'Cálculo Diferencial e Integral II'
#  'Desenvolvimento de Servidor Web' 'Gerência de Projetos'
#  'Projeto e Análise de Algoritmos' 'Ciência de Dados'
#  'Informação e Sociedade' 'Introdução à Inteligência Artificial'
#  'Projeto de Jogos Digitais' 'Atividades de Extensão II' 'Estatística'
#  'Informática na Educação' 'Governança de Tecnologia da Informação'
#  'Metodologia Científica e Tecnológica'
#  'Segurança de Tecnologia da Informação' 'Tópicos em Projeto de Software'
#  'Tópicos em Propriedade Intelectual' 'Ciência de Redes'
#  'Tópicos em Qualidade de Software' 'Fluxos em Redes'
#  'Tópicos em Verificação, Validação e Testes de Software'
#  'Gerenciamento de Redes e Serviços' 'Acessibilidade'
#  'Serviços de Rede e Multimídia' 'Tópicos em Engenharia de Requisitos'
#  'Técnicas de Programação Avançada' 'Aprendizagem Profunda']

# %%
# prompt: Crie em data_cr a coluna grade_programming1 com os valores únicos de MEDIA_FINAL por NOME_ATIV_CURRIC = 'TÉCNICAS DE PROGRAMAÇÃO' I atrelado a NOME_PESSOA
if data_cr["NOME_CURSO"].iloc[0] == "Sistemas de Informação - Bacharelado - Turno Integral (V/N)":
  filtered_data_cr = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "TÉCNICAS DE PROGRAMAÇÃO I"]

  data_cr["grade_programming1"] = filtered_data_cr.groupby("NOME_PESSOA")["MEDIA_FINAL"].apply(lambda x: x.unique())
  grade_programming1_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "TÉCNICAS DE PROGRAMAÇÃO I", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_programming1"] = grade_programming1_value

  grade_programming2_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "TÉCNICAS DE PROGRAMAÇÃO II", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_programming2"] = grade_programming2_value

  grade_basic_mat_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "MATEMÁTICA BÁSICA", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_basic_math"] = grade_basic_mat_value

  grade_calculus1_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "Cálculo Diferencial e Integral I", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_calculus1"] = grade_calculus1_value

  grade_linear_algebra_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "Álgebra Linear", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_linear_algebra"] = grade_linear_algebra_value

  grade_logic = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "Introdução à Lógica Computacional", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_logic"] = grade_logic

# %%
if data_cr["NOME_CURSO"].iloc[0]== "Matemática - Licenciatura - Turno Integral (Vepsertino/Noturno)":
  filtered_data_cr = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "TÉCNICAS DE PROGRAMAÇÃO I"]

  data_cr["grade_programming1"] = filtered_data_cr.groupby("NOME_PESSOA")["MEDIA_FINAL"].apply(lambda x: x.unique())
  grade_programming1_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "INTRODUÇÂO À CIÊNCIA DA COMPUTAÇAO", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_programming1"] = grade_programming1_value

  grade_programming2_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "GEOMETRIA-1", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_geometry1"] = grade_programming2_value

  grade_basic_mat_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "FUNDAMENTOS DE MATEMÁTICA-1", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_math_foundation"] = grade_basic_mat_value

  grade_calculus1_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "CÁLCULO 1A", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_calculus1"] = grade_calculus1_value

  grade_linear_algebra_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "GEOMETRIA ANALÍTICA", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_analytic_geometry"] = grade_linear_algebra_value

  grade_enviroment = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "EDUCAÇÃO AMBIENTAL E CIDADANIA", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_enviroment"] = grade_enviroment

# %%
if data_cr["NOME_CURSO"].iloc[0] == "Engenharia de Produção - Bac.- Hab. Prod. Cultura - Turno Noturno":
  filtered_data_cr = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "TÉCNICAS DE PROGRAMAÇÃO I"]

  data_cr["grade_programming1"] = filtered_data_cr.groupby("NOME_PESSOA")["MEDIA_FINAL"].apply(lambda x: x.unique())
  grade_programming1_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "PROGRAMAÇÃO-I", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_programming1"] = grade_programming1_value

  grade_basic_mat_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "CÁLCULO-0", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_calculus0"] = grade_basic_mat_value

  grade_calculus1_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "CÁLCULO-I", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_calculus1"] = grade_calculus1_value

  grade_linear_algebra_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "ÁLGEBRA LINEAR-I", "MEDIA_FINAL"].iloc[0]
  data_cr["grade_linear_algebra"] = grade_linear_algebra_value

  grade_eng_value = data_cr.loc[data_cr["NOME_ATIV_CURRIC"] == "INTRODUÇÃO À ENGENHARIA DE PRODUÇÃO"].iloc[0]
  data_cr["grade_eng_introduction"] = grade_eng_value

# %% [markdown]
# # Tratando cotas

# %%
# prompt: Printe todos os valores únicos de data_cr['DESCR_FORMA_INGRESSO']

print(data_cr['DESCR_FORMA_INGRESSO'].unique())
# Out:
# ['VE - Vestibular'
#  'TE - Transferência Externa - oriunda de outra instituição' 'EN - ENEM'
#  'EO -Transferência Ex-Ofício'
#  'PG - Programa de Estudantes - Convênio (PEC-G)'
#  'PD - Portador de Diploma de Nível Superior'
#  'TC - Transferência Interna-Curso não relacionado ao anterior'
#  'AE - Mobilidade Adadêmica Externa - ANDIFES'
#  'AE - Mobilidade Acadêmica IAE/IESCE'
#  'AE - Aluno Especial - Disciplina Isolada' 'SISU Ampla Concorrencia'
#  'SISU Escola Publica até 1,5 S.M. Preto, Pardo, Indígena'
#  'SISU Escola Publica, Indep de Renda: Preto, Pardo, Indígena'
#  'SISU Escola Publica até 1,5 S.M.'
#  'SISU Escola Publica - Indep. de Renda'
#  'SISU Escola Pública, Indep. de Renda : Índio'
#  'SISU Escola Pública até 1,5 S.M Preto e Pardo'
#  'SISU Escola Pública, Indep. de Renda : Preto e Pardo'
#  'SISU Escola Pública até 1,5 S.M Índio' 'DJ - Decisão Judicial'
#  'Pessoas com Deficiência']

# %%
# prompt: Faça um gráfico de pizza de data_cr['DESCR_FORMA_INGRESSO'] de valores que  startswith('SISU')

# Filtrar os valores que começam com 'SISU'
sisu_values = data_cr[data_cr['DESCR_FORMA_INGRESSO'].str.startswith('SISU', na=False)]['DESCR_FORMA_INGRESSO']

# Contar a frequência de cada valor
sisu_counts = sisu_values.value_counts()

# Criar o gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(sisu_counts, labels=sisu_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribuição de Ingressantes via SISU')
plt.show()

# %%
data_cr['renda'] = data_cr['DESCR_FORMA_INGRESSO'].apply(lambda x: 'baixa-renda' if x.startswith('SISU Escola Pública até 1,5 S.M') else 'não-baixa-renda')

# %%
data_cr['ingresso_atual'] = data_cr['DESCR_FORMA_INGRESSO'].apply(lambda x: 'nao-cotistas' if x == 'SISU Ampla Concorrencia' else
                                                         'cotistas' if x.startswith('SISU') else 'antes do SISU')

# %%
data_cr
# Out:
#        ID_PESSOA                 NOME_PESSOA  ID_ALUNO   MATR_ALUNO  \
# 0           1200   André Luiz Bione Martinez      1200  20002210014
# 1           1200   André Luiz Bione Martinez      1200  20002210014
# 2           1200   André Luiz Bione Martinez      1200  20002210014
# 3           1200   André Luiz Bione Martinez      1200  20002210014
# 4           1200   André Luiz Bione Martinez      1200  20002210014
# ...          ...                         ...       ...          ...
# 48635     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48636     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48637     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48638     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48639     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
#
#       NUM_VERSAO                                         NOME_CURSO  \
# 0     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 1     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 2     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 3     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 4     2000-02-01  Sistemas de Informação - Bacharelado - Turno I...
# ...          ...                                                ...
# 48635 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48636 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48637 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48638 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48639 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
#
#        COD_CURSO  ID_VERSAO_CURSO   ANO COD_ATIV_CURRIC  ... GPA4   year4  \
# 0            210               13  2000         TME0012  ...  NaN  2005.0
# 1            210               13  2000         TME0012  ...  NaN  2005.0
# 2            210               13  2000         HHI0033  ...  NaN  2005.0
# 3            210               13  2000         HHI0033  ...  NaN  2005.0
# 4            210               13  2000         TIN0005  ...  NaN  2005.0
# ...          ...              ...   ...             ...  ...  ...     ...
# 48635        210              737  2023         TIN0106  ...  NaN     NaN
# 48636        210              737  2023         TMT0043  ...  NaN     NaN
# 48637        210              737  2023         TIN0206  ...  NaN     NaN
# 48638        210              737  2023         TIN0207  ...  NaN     NaN
# 48639        210              737  2023         TIN0208  ...  NaN     NaN
#
#        grade_programming1 grade_programming2 grade_basic_math grade_calculus1  \
# 0                     8.0               10.0             10.0             7.4
# 1                     8.0               10.0             10.0             7.4
# 2                     8.0               10.0             10.0             7.4
# 3                     8.0               10.0             10.0             7.4
# 4                     8.0               10.0             10.0             7.4
# ...                   ...                ...              ...             ...
# 48635                 8.0               10.0             10.0             7.4
# 48636                 8.0               10.0             10.0             7.4
# 48637                 8.0               10.0             10.0             7.4
# 48638                 8.0               10.0             10.0             7.4
# 48639                 8.0               10.0             10.0             7.4
#
#        grade_linear_algebra  grade_logic            renda  ingresso_atual
# 0                       9.5          4.1  não-baixa-renda   antes do SISU
# 1                       9.5          4.1  não-baixa-renda   antes do SISU
# 2                       9.5          4.1  não-baixa-renda   antes do SISU
# 3                       9.5          4.1  não-baixa-renda   antes do SISU
# 4                       9.5          4.1  não-baixa-renda   antes do SISU
# ...                     ...          ...              ...             ...
# 48635                   9.5          4.1  não-baixa-renda    nao-cotistas
# 48636                   9.5          4.1  não-baixa-renda    nao-cotistas
# 48637                   9.5          4.1  não-baixa-renda    nao-cotistas
# 48638                   9.5          4.1  não-baixa-renda    nao-cotistas
# 48639                   9.5          4.1  não-baixa-renda    nao-cotistas
#
# [48640 rows x 41 columns]

# %%
data_cr = data_cr[data_cr['ingresso_atual'].isin(['nao-cotistas', 'cotistas'])]
data_cr
# Out:
#        ID_PESSOA                 NOME_PESSOA  ID_ALUNO   MATR_ALUNO  \
# 27673      94824               Danton Coelho     83481  20131210001
# 27674      94824               Danton Coelho     83481  20131210001
# 27675      94824               Danton Coelho     83481  20131210001
# 27676      94824               Danton Coelho     83481  20131210001
# 27677      94824               Danton Coelho     83481  20131210001
# ...          ...                         ...       ...          ...
# 48635     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48636     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48637     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48638     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
# 48639     169523  MATHEUS DA FONSECA MARQUES    144859  20232210034
#
#       NUM_VERSAO                                         NOME_CURSO  \
# 27673 2008-01-01  Sistemas de Informação - Bacharelado - Turno I...
# 27674 2008-01-01  Sistemas de Informação - Bacharelado - Turno I...
# 27675 2008-01-01  Sistemas de Informação - Bacharelado - Turno I...
# 27676 2008-01-01  Sistemas de Informação - Bacharelado - Turno I...
# 27677 2008-01-01  Sistemas de Informação - Bacharelado - Turno I...
# ...          ...                                                ...
# 48635 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48636 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48637 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48638 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
# 48639 2023-02-01  Sistemas de Informação - Bacharelado - Turno I...
#
#        COD_CURSO  ID_VERSAO_CURSO   ANO COD_ATIV_CURRIC  ... GPA4   year4  \
# 27673        210              339  2013         TIN0117  ...  1.4  2004.0
# 27674        210              339  2013         TIN0150  ...  1.4  2004.0
# 27675        210              339  2013         TIN0013  ...  1.4  2004.0
# 27676        210              339  2013         TIN0118  ...  1.4  2004.0
# 27677        210              339  2013         TIN0115  ...  1.4  2004.0
# ...          ...              ...   ...             ...  ...  ...     ...
# 48635        210              737  2023         TIN0106  ...  NaN     NaN
# 48636        210              737  2023         TMT0043  ...  NaN     NaN
# 48637        210              737  2023         TIN0206  ...  NaN     NaN
# 48638        210              737  2023         TIN0207  ...  NaN     NaN
# 48639        210              737  2023         TIN0208  ...  NaN     NaN
#
#        grade_programming1 grade_programming2 grade_basic_math grade_calculus1  \
# 27673                 8.0               10.0             10.0             7.4
# 27674                 8.0               10.0             10.0             7.4
# 27675                 8.0               10.0             10.0             7.4
# 27676                 8.0               10.0             10.0             7.4
# 27677                 8.0               10.0             10.0             7.4
# ...                   ...                ...              ...             ...
# 48635                 8.0               10.0             10.0             7.4
# 48636                 8.0               10.0             10.0             7.4
# 48637                 8.0               10.0             10.0             7.4
# 48638                 8.0               10.0             10.0             7.4
# 48639                 8.0               10.0             10.0             7.4
#
#        grade_linear_algebra  grade_logic            renda  ingresso_atual
# 27673                   9.5          4.1  não-baixa-renda    nao-cotistas
# 27674                   9.5          4.1  não-baixa-renda    nao-cotistas
# 27675                   9.5          4.1  não-baixa-renda    nao-cotistas
# 27676                   9.5          4.1  não-baixa-renda    nao-cotistas
# 27677                   9.5          4.1  não-baixa-renda    nao-cotistas
# ...                     ...          ...              ...             ...
# 48635                   9.5          4.1  não-baixa-renda    nao-cotistas
# 48636                   9.5          4.1  não-baixa-renda    nao-cotistas
# 48637                   9.5          4.1  não-baixa-renda    nao-cotistas
# 48638                   9.5          4.1  não-baixa-renda    nao-cotistas
# 48639                   9.5          4.1  não-baixa-renda    nao-cotistas
#
# [20266 rows x 41 columns]

# %% [markdown]
# # Lendo evasão

# %%
data_evasao = pd.read_excel("/content/gdrive/My Drive/dados_mestrado/Alunos 14Maio2024.xlsx")

# %%
data_evasao
# Out:
#        ID_PESSOA                     NOME_PESSOA SEXO        DT_NASCIMENTO  \
# 0         108278   Alan Oliveira Rodrigues Ramos    M  1987-07-17 00:00:00
# 1         138874     Alberto Renan Dias da Silva    M  1992-11-20 00:00:00
# 2         118637  Alcebiades de Calazans Barbosa    M  1971-02-15 00:00:00
# 3         138875            Alciley Dias Pereira    M  1963-11-01 00:00:00
# 4         138875            Alciley Dias Pereira    M  1963-11-01 00:00:00
# ...          ...                             ...  ...                  ...
# 65530     155882        Wilson De Souza Cordeiro    M  1983-04-24 00:00:00
# 65531     145602          Wladimir Pedro Barbosa    M  1962-03-03 00:00:00
# 65532     145564       Ygor Luis Araujo Da Silva    M  1997-05-26 00:00:00
# 65533     145488            Ygor Maciel De Abreu    M  1996-04-22 00:00:00
# 65534      41541          Adriana Fagundes Gomes    F  1986-05-14 00:00:00
#
#                                    FORMA_INGRESSO  \
# 0               PA - Processo Seletivo - Mestrado
# 1               PA - Processo Seletivo - Mestrado
# 2               PA - Processo Seletivo - Mestrado
# 3               PA - Processo Seletivo - Mestrado
# 4      Processo Seletivo Mestrado  - Pessoa negra
# ...                                           ...
# 65530                             VE - Vestibular
# 65531                             VE - Vestibular
# 65532                             VE - Vestibular
# 65533                             VE - Vestibular
# 65534                             VE - Vestibular
#
#                                    FORMA_EVASAO COD_CURSO  \
# 0                       ABA - Abandono do curso     01P2F
# 1                         CON - Curso concluído     01P2F
# 2                         CON - Curso concluído     01P2F
# 3      DES - Desligamento (curso não concluido)     01P2F
# 4      DES - Desligamento (curso não concluido)     01P2F
# ...                                         ...       ...
# 65530                                Sem evasão    601BRO
# 65531         CAN - Cancelamento Geral do curso    601BRO
# 65532         CAN - Cancelamento Geral do curso    601BRO
# 65533         CAN - Cancelamento Geral do curso    601BRO
# 65534         CAN - Cancelamento Geral do curso    601CGD
#
#                                             NOME_UNIDADE   MATR_ALUNO  \
# 0      Matemática em Rede Nacional - Mestrado Profiss...   15101P2F01
# 1      Matemática em Rede Nacional - Mestrado Profiss...  19101P2MP01
# 2      Matemática em Rede Nacional - Mestrado Profiss...   16101P2F01
# 3      Matemática em Rede Nacional - Mestrado Profiss...  19101P2MP02
# 4      Matemática em Rede Nacional - Mestrado Profiss...  21101P2MP01
# ...                                                  ...          ...
# 65530  Matemática - Licenciatura a distância - Polo B...  21216010010
# 65531  Matemática - Licenciatura a distância - Polo B...  18116010057
# 65532  Matemática - Licenciatura a distância - Polo B...  17216010155
# 65533  Matemática - Licenciatura a distância - Polo B...  16216010118
# 65534  Matemática - Licenciatura a distância - Polo C...  20081601047
#
#                 NUM_VERSAO   PERIODO_INGRESSO            DT_EVASAO  \
# 0      2011-01-01 00:00:00  2015/1°. semestre  2016-03-28 00:00:00
# 1      2011-01-01 00:00:00  2019/1°. semestre  2021-08-12 00:00:00
# 2      2011-01-01 00:00:00  2016/1°. semestre  2019-02-05 00:00:00
# 3      2011-01-01 00:00:00  2019/1°. semestre  2020-12-23 00:00:00
# 4      2011-01-01 00:00:00  2021/1°. semestre  2023-05-02 00:00:00
# ...                    ...                ...                  ...
# 65530  2015-02-01 00:00:00  2021/2°. semestre                  NaN
# 65531  2015-02-01 00:00:00  2018/1°. semestre  2023-12-30 00:00:00
# 65532  2015-02-01 00:00:00  2017/2°. semestre  2018-01-01 00:00:00
# 65533  2015-02-01 00:00:00  2016/2°. semestre  2023-12-31 00:00:00
# 65534  2012-02-01 00:00:00  2008/1°. semestre  2014-01-01 00:00:00
#
#           PERIODO_EVASAO  CPF_MASCARA
# 0      2016/1°. semestre  12057013707
# 1      2021/1°. semestre  14380184790
# 2      2019/1°. semestre  99431785749
# 3      2020/1°. semestre  75453088753
# 4      2023/1°. semestre  75453088753
# ...                  ...          ...
# 65530                NaN   9315158741
# 65531  2023/2°. semestre  75639246715
# 65532  2018/1°. semestre  17201339729
# 65533  2023/2°. semestre  15808268737
# 65534  2014/1°. semestre  11252376782
#
# [65535 rows x 14 columns]

# %% [markdown]
# # Tratando o CPF

# %%
# No valor de data_evasao['CPF_TRATADO'] que tiver 10 caracteres, adicione um 0 na frente.
data_evasao['CPF_MASCARA'] = data_evasao['CPF_MASCARA'].astype(str)
for i in range(10, 0, -1):
    data_evasao['CPF_MASCARA'] = np.where(data_evasao['CPF_MASCARA'].str.len() == i, '0' * (11 - i) + data_evasao['CPF_MASCARA'], data_evasao['CPF_MASCARA'])

# %%
# Função para substituir os caracteres
def tratar_cpf(cpf):
    return '***' + cpf[3:-2] + '**'

# Aplicando a função na coluna CPF_MASCARA e criando a coluna CPF_TRATADO
data_evasao['CPF_TRATADO'] = data_evasao['CPF_MASCARA'].apply(tratar_cpf)

# %%
data_evasao
# Out:
#        ID_PESSOA                     NOME_PESSOA SEXO        DT_NASCIMENTO  \
# 0         108278   Alan Oliveira Rodrigues Ramos    M  1987-07-17 00:00:00
# 1         138874     Alberto Renan Dias da Silva    M  1992-11-20 00:00:00
# 2         118637  Alcebiades de Calazans Barbosa    M  1971-02-15 00:00:00
# 3         138875            Alciley Dias Pereira    M  1963-11-01 00:00:00
# 4         138875            Alciley Dias Pereira    M  1963-11-01 00:00:00
# ...          ...                             ...  ...                  ...
# 65530     155882        Wilson De Souza Cordeiro    M  1983-04-24 00:00:00
# 65531     145602          Wladimir Pedro Barbosa    M  1962-03-03 00:00:00
# 65532     145564       Ygor Luis Araujo Da Silva    M  1997-05-26 00:00:00
# 65533     145488            Ygor Maciel De Abreu    M  1996-04-22 00:00:00
# 65534      41541          Adriana Fagundes Gomes    F  1986-05-14 00:00:00
#
#                                    FORMA_INGRESSO  \
# 0               PA - Processo Seletivo - Mestrado
# 1               PA - Processo Seletivo - Mestrado
# 2               PA - Processo Seletivo - Mestrado
# 3               PA - Processo Seletivo - Mestrado
# 4      Processo Seletivo Mestrado  - Pessoa negra
# ...                                           ...
# 65530                             VE - Vestibular
# 65531                             VE - Vestibular
# 65532                             VE - Vestibular
# 65533                             VE - Vestibular
# 65534                             VE - Vestibular
#
#                                    FORMA_EVASAO COD_CURSO  \
# 0                       ABA - Abandono do curso     01P2F
# 1                         CON - Curso concluído     01P2F
# 2                         CON - Curso concluído     01P2F
# 3      DES - Desligamento (curso não concluido)     01P2F
# 4      DES - Desligamento (curso não concluido)     01P2F
# ...                                         ...       ...
# 65530                                Sem evasão    601BRO
# 65531         CAN - Cancelamento Geral do curso    601BRO
# 65532         CAN - Cancelamento Geral do curso    601BRO
# 65533         CAN - Cancelamento Geral do curso    601BRO
# 65534         CAN - Cancelamento Geral do curso    601CGD
#
#                                             NOME_UNIDADE   MATR_ALUNO  \
# 0      Matemática em Rede Nacional - Mestrado Profiss...   15101P2F01
# 1      Matemática em Rede Nacional - Mestrado Profiss...  19101P2MP01
# 2      Matemática em Rede Nacional - Mestrado Profiss...   16101P2F01
# 3      Matemática em Rede Nacional - Mestrado Profiss...  19101P2MP02
# 4      Matemática em Rede Nacional - Mestrado Profiss...  21101P2MP01
# ...                                                  ...          ...
# 65530  Matemática - Licenciatura a distância - Polo B...  21216010010
# 65531  Matemática - Licenciatura a distância - Polo B...  18116010057
# 65532  Matemática - Licenciatura a distância - Polo B...  17216010155
# 65533  Matemática - Licenciatura a distância - Polo B...  16216010118
# 65534  Matemática - Licenciatura a distância - Polo C...  20081601047
#
#                 NUM_VERSAO   PERIODO_INGRESSO            DT_EVASAO  \
# 0      2011-01-01 00:00:00  2015/1°. semestre  2016-03-28 00:00:00
# 1      2011-01-01 00:00:00  2019/1°. semestre  2021-08-12 00:00:00
# 2      2011-01-01 00:00:00  2016/1°. semestre  2019-02-05 00:00:00
# 3      2011-01-01 00:00:00  2019/1°. semestre  2020-12-23 00:00:00
# 4      2011-01-01 00:00:00  2021/1°. semestre  2023-05-02 00:00:00
# ...                    ...                ...                  ...
# 65530  2015-02-01 00:00:00  2021/2°. semestre                  NaN
# 65531  2015-02-01 00:00:00  2018/1°. semestre  2023-12-30 00:00:00
# 65532  2015-02-01 00:00:00  2017/2°. semestre  2018-01-01 00:00:00
# 65533  2015-02-01 00:00:00  2016/2°. semestre  2023-12-31 00:00:00
# 65534  2012-02-01 00:00:00  2008/1°. semestre  2014-01-01 00:00:00
#
#           PERIODO_EVASAO  CPF_MASCARA  CPF_TRATADO
# 0      2016/1°. semestre  12057013707  ***570137**
# 1      2021/1°. semestre  14380184790  ***801847**
# 2      2019/1°. semestre  99431785749  ***317857**
# 3      2020/1°. semestre  75453088753  ***530887**
# 4      2023/1°. semestre  75453088753  ***530887**
# ...                  ...          ...          ...
# 65530                NaN  09315158741  ***151587**
# 65531  2023/2°. semestre  75639246715  ***392467**
# 65532  2018/1°. semestre  17201339729  ***013397**
# 65533  2023/2°. semestre  15808268737  ***082687**
# 65534  2014/1°. semestre  11252376782  ***523767**
#
# [65535 rows x 15 columns]

# %% [markdown]
# # Tratando a evasão

# %%
# prompt: Liste todos os valores únicos de data_evasao['FORMA_EVASAO']

print(data_evasao['FORMA_EVASAO'].unique())
# Out:
# ['ABA - Abandono do curso' 'CON - Curso concluído'
#  'DES - Desligamento (curso não concluido)'
#  'CAN - Cancelamento Geral do curso' 'Sem evasão'
#  'DES - Desistência (pós graduação)' 'JUB - Jubilamento'
#  'APO - Aluno Especial - Disciplina Isolada' 'Desistência SiSU'
#  'MST - Mudança de nível sem titulação (pós-graduação)'
#  'TIC - Transferência Interna' 'FAL - Falecimento do discente'
#  'Passagem Direta - Pós-Graduação' 'TTU - Transferência de Turno'
#  'Não identificada (vide pasta do aluno)' 'Reopção de Curso'
#  'TNE - Transferido para outa Instituição'
#  'APO - Apostilamento - Conclusão de Habilitação' 'Aprovado'
#  'APO -Conclusão da Mobilidade Acadêmica Externa - IAE/IESCE'
#  'APO -Conclusão a Mobilidade Acadêmica Externa - ANDIFES'
#  'MCT - Mudança de nível com titulação (pós-graduação)']

# %%
# prompt: Substitua os valores de data_evasao['FORMA_EVASAO'] que sejam 'CON - Curso concluído' por 'Concluido'

data_evasao['FORMA_EVASAO'] = data_evasao['FORMA_EVASAO'].replace('CON - Curso concluído', 'Concluido')

# %%
# prompt: Substitua os valores de data_evasao['FORMA_EVASAO'] que sejam 'ABA - Abandono do curso' ou 'DES - Desligamento (curso não concluido)' ou 'CAN - Cancelamento Geral do curso' ou 'DES - Desistência (pós graduação)' ou 'JUB - Jubilamento' por 'Evadido'

data_evasao['FORMA_EVASAO'] = data_evasao['FORMA_EVASAO'].replace(['ABA - Abandono do curso', 'DES - Desligamento (curso não concluido)', 'CAN - Cancelamento Geral do curso', 'DES - Desistência (pós graduação)', 'JUB - Jubilamento'], 'Evadido')

# %%
# prompt: Tire as linhas de data_evasao cujos os valores não sejam 'Concluido' ou 'Evadido'

data_evasao = data_evasao[data_evasao['FORMA_EVASAO'].isin(['Concluido', 'Evadido'])]

# %%
data_evasao
# Out:
#        ID_PESSOA                     NOME_PESSOA SEXO        DT_NASCIMENTO  \
# 0         108278   Alan Oliveira Rodrigues Ramos    M  1987-07-17 00:00:00
# 1         138874     Alberto Renan Dias da Silva    M  1992-11-20 00:00:00
# 2         118637  Alcebiades de Calazans Barbosa    M  1971-02-15 00:00:00
# 3         138875            Alciley Dias Pereira    M  1963-11-01 00:00:00
# 4         138875            Alciley Dias Pereira    M  1963-11-01 00:00:00
# ...          ...                             ...  ...                  ...
# 65529     145487             Wilma Gomes De Lima    F  1966-03-28 00:00:00
# 65531     145602          Wladimir Pedro Barbosa    M  1962-03-03 00:00:00
# 65532     145564       Ygor Luis Araujo Da Silva    M  1997-05-26 00:00:00
# 65533     145488            Ygor Maciel De Abreu    M  1996-04-22 00:00:00
# 65534      41541          Adriana Fagundes Gomes    F  1986-05-14 00:00:00
#
#                                    FORMA_INGRESSO FORMA_EVASAO COD_CURSO  \
# 0               PA - Processo Seletivo - Mestrado      Evadido     01P2F
# 1               PA - Processo Seletivo - Mestrado    Concluido     01P2F
# 2               PA - Processo Seletivo - Mestrado    Concluido     01P2F
# 3               PA - Processo Seletivo - Mestrado      Evadido     01P2F
# 4      Processo Seletivo Mestrado  - Pessoa negra      Evadido     01P2F
# ...                                           ...          ...       ...
# 65529                             VE - Vestibular      Evadido    601BRO
# 65531                             VE - Vestibular      Evadido    601BRO
# 65532                             VE - Vestibular      Evadido    601BRO
# 65533                             VE - Vestibular      Evadido    601BRO
# 65534                             VE - Vestibular      Evadido    601CGD
#
#                                             NOME_UNIDADE   MATR_ALUNO  \
# 0      Matemática em Rede Nacional - Mestrado Profiss...   15101P2F01
# 1      Matemática em Rede Nacional - Mestrado Profiss...  19101P2MP01
# 2      Matemática em Rede Nacional - Mestrado Profiss...   16101P2F01
# 3      Matemática em Rede Nacional - Mestrado Profiss...  19101P2MP02
# 4      Matemática em Rede Nacional - Mestrado Profiss...  21101P2MP01
# ...                                                  ...          ...
# 65529  Matemática - Licenciatura a distância - Polo B...  16216010006
# 65531  Matemática - Licenciatura a distância - Polo B...  18116010057
# 65532  Matemática - Licenciatura a distância - Polo B...  17216010155
# 65533  Matemática - Licenciatura a distância - Polo B...  16216010118
# 65534  Matemática - Licenciatura a distância - Polo C...  20081601047
#
#                 NUM_VERSAO   PERIODO_INGRESSO            DT_EVASAO  \
# 0      2011-01-01 00:00:00  2015/1°. semestre  2016-03-28 00:00:00
# 1      2011-01-01 00:00:00  2019/1°. semestre  2021-08-12 00:00:00
# 2      2011-01-01 00:00:00  2016/1°. semestre  2019-02-05 00:00:00
# 3      2011-01-01 00:00:00  2019/1°. semestre  2020-12-23 00:00:00
# 4      2011-01-01 00:00:00  2021/1°. semestre  2023-05-02 00:00:00
# ...                    ...                ...                  ...
# 65529  2015-02-01 00:00:00  2016/2°. semestre  2019-01-01 00:00:00
# 65531  2015-02-01 00:00:00  2018/1°. semestre  2023-12-30 00:00:00
# 65532  2015-02-01 00:00:00  2017/2°. semestre  2018-01-01 00:00:00
# 65533  2015-02-01 00:00:00  2016/2°. semestre  2023-12-31 00:00:00
# 65534  2012-02-01 00:00:00  2008/1°. semestre  2014-01-01 00:00:00
#
#           PERIODO_EVASAO  CPF_MASCARA  CPF_TRATADO
# 0      2016/1°. semestre  12057013707  ***570137**
# 1      2021/1°. semestre  14380184790  ***801847**
# 2      2019/1°. semestre  99431785749  ***317857**
# 3      2020/1°. semestre  75453088753  ***530887**
# 4      2023/1°. semestre  75453088753  ***530887**
# ...                  ...          ...          ...
# 65529  2019/1°. semestre  88418430710  ***184307**
# 65531  2023/2°. semestre  75639246715  ***392467**
# 65532  2018/1°. semestre  17201339729  ***013397**
# 65533  2023/2°. semestre  15808268737  ***082687**
# 65534  2014/1°. semestre  11252376782  ***523767**
#
# [44261 rows x 15 columns]

# %% [markdown]
# # Juntando os dois bancos de dados

# %%
if data_cr["NOME_CURSO"].iloc[0] == "Sistemas de Informação - Bacharelado - Turno Integral (V/N)":
  data_unificado = pd.merge(
      data_cr[['MATR_ALUNO', 'renda','NOME_PESSOA', 'ANO_EVASAO', 'ingresso_atual', 'NOME_CURSO', 'NOME_ATIV_CURRIC', 'MEDIA_FINAL', 'SEXO' , 'DESCR_SITUACAO', 'ANO_INGRESSO', 'ANO', 'CR_NO_PERIODO', 'CR_ATUAL','GPA1', 'GPA2', 'GPA3', 'GPA4', 'year4','grade_programming1', 'grade_programming2', 'grade_basic_math','grade_calculus1', 'grade_linear_algebra', "grade_logic"]],
      data_evasao[['NOME_PESSOA', 'FORMA_EVASAO', 'CPF_TRATADO' ,'CPF_MASCARA', 'DT_EVASAO']],
      on='NOME_PESSOA',
      how='inner'
  )
  data_unificado

# %%
if data_cr["NOME_CURSO"].iloc[0] == "Matemática - Licenciatura - Turno Integral (Vepsertino/Noturno)":
  data_unificado = pd.merge(
      data_cr[['MATR_ALUNO','renda','NOME_PESSOA', 'ANO_EVASAO', 'ingresso_atual', 'NOME_CURSO', 'NOME_ATIV_CURRIC', 'MEDIA_FINAL', 'SEXO' , 'DESCR_SITUACAO', 'ANO_INGRESSO', 'ANO', 'CR_NO_PERIODO', 'CR_ATUAL','GPA1', 'GPA2', 'GPA3', 'GPA4', 'year4','grade_programming1', 'grade_geometry1', 'grade_math_foundation','grade_calculus1', 'grade_analytic_geometry', "grade_enviroment"]],
      data_evasao[['NOME_PESSOA', 'FORMA_EVASAO', 'CPF_TRATADO' ,'CPF_MASCARA', 'DT_EVASAO']],
      on='NOME_PESSOA',
      how='inner'
  )
  data_unificado

# %%
if data_cr["NOME_CURSO"].iloc[0] == "Engenharia de Produção - Bac.- Hab. Prod. Cultura - Turno Noturno":
  data_unificado = pd.merge(
      data_cr[['MATR_ALUNO','renda','NOME_PESSOA', 'ANO_EVASAO', 'ingresso_atual', 'NOME_CURSO', 'NOME_ATIV_CURRIC', 'MEDIA_FINAL', 'SEXO' , 'DESCR_SITUACAO', 'ANO_INGRESSO', 'ANO', 'CR_NO_PERIODO', 'CR_ATUAL','GPA1', 'GPA2', 'GPA3', 'GPA4', 'year4','grade_programming1', 'grade_calculus0','grade_calculus1', 'grade_linear_algebra', "grade_eng_introduction"]],
      data_evasao[['NOME_PESSOA', 'FORMA_EVASAO', 'CPF_TRATADO' ,'CPF_MASCARA', 'DT_EVASAO']],
      on='NOME_PESSOA',
      how='inner'
  )
  data_unificado

# %%
# prompt: Coloque todos os valores de NOME_PESSOA em caixa alta

data_unificado['NOME_PESSOA'] = data_unificado['NOME_PESSOA'].str.upper()

# %%
# prompt: Faça o download de data_unificado em formato xlsx
file_name = file_name+"_1.xlsx"
data_unificado.to_excel("/content/gdrive/My Drive/dados_mestrado/"+file_name)
